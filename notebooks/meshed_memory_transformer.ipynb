# %% [markdown]
# # Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ./data/coco
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip -d ./data/coco
# !rm annotations_trainval2017.zip
# Out:
# --2022-11-20 11:31:12--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.18.80, 52.216.107.132, 3.5.7.101, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.18.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  96.5MB/s    in 2.5s
#
# 2022-11-20 11:31:15 (96.5 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: ./data/coco/annotations/instances_train2017.json
#   inflating: ./data/coco/annotations/instances_val2017.json
#   inflating: ./data/coco/annotations/captions_train2017.json
#   inflating: ./data/coco/annotations/captions_val2017.json
#   inflating: ./data/coco/annotations/person_keypoints_train2017.json
# ...

# %%
# !cp "./drive/MyDrive/artwork_captioning/data/features/coco_2017_detections.hdf5" .

# %% [markdown]
# # Setup python environment

# %%
# !rm -rf meshed_memory_transformer/
# !git clone https://github.com/rbarile17/meshed_memory_transformer.git
# Out:
# Cloning into 'meshed_memory_transformer'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 198 (delta 62), reused 88 (delta 41), pack-reused 74
# Receiving objects: 100% (198/198), 7.58 MiB | 44.11 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
# !python -m spacy download "en_core_web_trf"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 460.3 MB 27 kB/s
# ...
#      |████████████████████████████████| 53 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 22.5 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 67.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 70.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 49.1 MB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %% [markdown]
# # Training

# %%
# %cd meshed_memory_transformer/
from train import train

train(
    exp_name = 'coco_2017_train',
    batch_size = 100,
    workers = 0,
    m = 40,
    head = 8,
    warmup = 10000,
    resume_last = False,
    resume_best = False,
    features_path = './coco_2017_detections.hdf5',
    annotation_folder = './data/coco/annotations',
    logs_folder = './drive/MyDrive/artwork_captioning/captioning_output/tensorboard_logs')
