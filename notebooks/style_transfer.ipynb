# %% [markdown]
# # Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ./data/coco/
# !unrar x ./drive/MyDrive/artwork_captioning/data/datasets/coco/val2017.rar ./data/coco

# %%
# !mkdir -p ./data/artgraphv2
# !unrar x ./drive/MyDrive/artwork_captioning/data/datasets/artgraphv2/imagesf2.rar ./data/artgraphv2

# %% [markdown]
# # Setup python

# %%
# !rm -rf styleflow_content_fixed_I2I
# !git clone https://github.com/rbarile17/styleflow_content_fixed_I2I.git
# Out:
# Cloning into 'styleflow_content_fixed_I2I'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 179 (delta 60), reused 80 (delta 32), pack-reused 62
# Receiving objects: 100% (179/179), 82.69 MiB | 48.89 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 5.0 MB/s
# ...

# %% [markdown]
# # Test

# %%
from styleflow_content_fixed_I2I.test import test

test(
    "./drive/MyDrive/artwork_captioning/style_transfer_config/coco_val2017_wikiart/coco_val2017_wikiart.yml",
    "./drive/MyDrive/artwork_captioning/style_transfer_output/coco_train2017_wikiart/model_save/187500.ckpt.pth.tar"
)
